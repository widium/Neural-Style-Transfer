# %%
from model.content_model import Model_Content_Representation
from model.style_model import Model_Style_Representation
from model.neural_style_transfert import Model_Style_Transfert

# %%
Style_Model = Model_Style_Representation()
Content_Model = Model_Content_Representation()
Neural_Style_Transfert = Model_Style_Transfert(noise_ratio=0.45)
# Out:
# 2022-11-21 11:08:27.167836: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 11:08:27.201588: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 11:08:27.201851: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 11:08:27.203068: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# ...

# %%
# Style_Model.import_img("img/style/waves.png")
# Style_Model.recreate_style(num_epochs=100)
# Content_Model.import_img(content_img="img/content/content_img.jpg")
# Content_Model.recreate_content(num_epochs=100)
Neural_Style_Transfert.import_img(content_img="img/content/content_img.jpg", 
                                  style_img="img/style/waves.png")
Neural_Style_Transfert.transfert_style(num_epochs=3000, create_gif=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/widium/Programming/AI/Neural-Style-Transfer/test.ipynb Cell 3 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/home/widium/Programming/AI/Neural-Style-Transfer/test.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> # Style_Model.import_img("img/style/waves.png")
#       <a href='vscode-notebook-cell:/home/widium/Programming/AI/Neural-Style-Transfer/test.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> # Style_Model.recreate_style(num_epochs=100)
#       <a href='vscode-notebook-cell:/home/widium/Programming/AI/Neural-Style-Transfer/test.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> # Content_Model.import_img(content_img="img/content/content_img.jpg")
#       <a href='vscode-notebook-cell:/home/widium/Programming/AI/Neural-Style-Transfer/test.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> # Content_Model.recreate_content(num_epochs=100)
# ...

# %%
def make_gif(frames : list):
    frame_one = frames[0]
    frame_one.save("img/finish/convert.gif", 
                   format="GIF", 
                   append_images=frames,
                   save_all=True, 
                   duration=100, 
                   loop=0)
    
make_gif(Neural_Style_Transfert.frames)

# %%
i = 0
for img in Neural_Style_Transfert.frames :
    i += 1
    img.save(f"img/test/{i}.png")

# %%
from IPython.display import clear_output
def display_generated_img(generated_img):
    
    clear_output(wait=True)
    display(generated_img)
