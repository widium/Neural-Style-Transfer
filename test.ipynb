# %%
from model.content_model import Model_Content_Representation
from model.style_model import Model_Style_Representation
from model.neural_style_transfert import Model_Style_Transfert

# %%
Style_Model = Model_Style_Representation()
Content_Model = Model_Content_Representation()
Neural_Style_Transfert = Model_Style_Transfert()
# Out:
# 2022-11-16 06:09:29.734131: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 06:09:29.754812: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 06:09:29.754957: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 06:09:29.755266: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# ...

# %%
Neural_Style_Transfert.import_img('img/content/content_img.jpg','img/style/waves.png')

# %%
Neural_Style_Transfert.transfert_style(num_epochs=100, create_gif=True)
