# %%
import sys
sys.path.append('..')

from model.style_model import Model_Style_Representation

# %% [markdown]
# ### Initialize Model for Style Representation

# %%
Style_Model = Model_Style_Representation()
# Out:
# 2022-11-21 15:26:23.511628: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 15:26:23.560611: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 15:26:23.561016: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 15:26:23.562840: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# ...

# %% [markdown]
# ### Import Style Image and Initialize Generated Image

# %%
Style_Model.import_img("../img/style/fractal.png")

# %% [markdown]
# ### Recreate Style
# if you want a gif and a subplot set argument of `recreate_style` as :
# - `create_gif=True`
# - `name="<your output name>"`

# %%
Style_Model.recreate_style(num_epochs=3000, 
                           create_gif=True, 
                           name="test")

# %% [markdown]
# ### Display Generated Style

# %%
from function.image import tensor_to_image
from IPython.display import display

display(tensor_to_image(Style_Model.generated_img))
# Out:
# <PIL.Image.Image image mode=RGB size=607x605>
